# %%
import pickle

# %%
with open("../models/seq.pkl", "rb") as f:
    seq = pickle.load(f)

# %%
seq
# Out:
# array([[    9,  1072,  4702, ...,     0,     0,     0],
#        [ 4702,   446,  4053, ...,     0,     0,     0],
#        [    9,  1072,  4702, ...,     0,     0,     0],
#        ...,
#        [ 4702,     1,   596, ...,     0,     0,     0],
#        [ 4702, 14443,  4472, ...,     0,     0,     0],
#        [ 4702,     1,  3987, ...,     0,     0,     0]], dtype=int32)

# %%
from tensorflow.keras.models import load_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from tensorflow.keras.models import load_model
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip freeze| grep tensor > temp
# !pip uninstall -r temp
# !rm temp
# Out:
# Found existing installation: tensorboard 2.13.0
# Uninstalling tensorboard-2.13.0:
#   Would remove:
#     /Users/kiran/Code/data-298/venv/bin/tensorboard
#     /Users/kiran/Code/data-298/venv/lib/python3.9/site-packages/tensorboard-2.13.0.dist-info/*
#     /Users/kiran/Code/data-298/venv/lib/python3.9/site-packages/tensorboard/*
#   Would not remove (outside of prefix):
#     /Users/kiran/Library/Caches/com.apple.python/Users/kiran/Code/data-298/venv/lib/python3.9/site-packages/tensorboard/__init__.cpython-39.pyc
#     /Users/kiran/Library/Caches/com.apple.python/Users/kiran/Code/data-298/venv/lib/python3.9/site-packages/tensorboard/_vendor/__init__.cpython-39.pyc
#     /Users/kiran/Library/Caches/com.apple.python/Users/kiran/Code/data-298/venv/lib/python3.9/site-packages/tensorboard/_vendor/bleach/__init__.cpython-39.pyc
#     /Users/kiran/Library/Caches/com.apple.python/Users/kiran/Code/data-298/venv/lib/python3.9/site-packages/tensorboard/_vendor/bleach/callbacks.cpython-39.pyc
# ...

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import keras
#
# ModuleNotFoundError: No module named 'keras'

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# astunparse==1.6.3
# bcrypt==4.0.1
# cachetools==5.3.0
# certifi==2023.5.7
# cffi==1.15.1
# charset-normalizer==3.1.0
# click==8.1.3
# dnspython==2.3.0
# Flask==2.2.3
# Flask-Cors==3.0.10
# Flask-JSGlue==0.3.1
# flatbuffers==23.5.9
# gast==0.4.0
# google-auth==2.18.0
# google-auth-oauthlib==1.0.0
# google-pasta==0.2.0
# grpcio==1.54.2
# h5py==3.8.0
# idna==3.4
# importlib-metadata==6.1.0
# itsdangerous==2.1.2
# Jinja2==3.1.2
# joblib==1.2.0
# keras==2.12.0
# libclang==16.0.0
# Markdown==3.4.3
# MarkupSafe==2.1.2
# numpy==1.24.2
# oauthlib==3.2.2
# opt-einsum==3.3.0
# packaging==23.1
# pandas==2.0.0
# pickle5==0.0.11
# protobuf==4.23.0
# pyasn1==0.5.0
# pyasn1-modules==0.3.0
# pycparser==2.21
# pymongo==4.3.3
# pyScss==1.4.0
# python-dateutil==2.8.2
# pytz==2023.3
# requests==2.30.0
# requests-oauthlib==1.3.1
# rsa==4.9
# scikit-learn==1.2.2
# scipy==1.10.1
# six==1.16.0
# tensorboard==2.13.0
# ...
